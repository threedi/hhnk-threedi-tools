# %% [markdown]
# # Vergelijkingstool starten
#
# Klik op **Run** om de Vergelijkingstool te starten.
#
# Meer informatie over het gebruik van de tool is beschikbaar via de knop **User Guide**.

# %%
from hhnk_threedi_tools.core.vergelijkingstool.gui.vergelijkingstool_gui import (
    VergelijkingstoolGUI,
)

# Launch the GUI
VergelijkingstoolGUI()
